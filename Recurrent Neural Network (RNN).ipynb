# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan3106/Deep-Learning/blob/main/Recurrent%20Neural%20Network%20(RNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
story = [
    "Sarah woke up early to prepare for her first day at work.",
    "She looked outside and saw heavy rain falling.",
    "Her umbrella was broken, so she borrowed one from her neighbor.",
    "The bus arrived ten minutes late.",
    "She met an elderly woman who smiled warmly.",
    "Sarah offered her seat to the woman.",
    "The woman thanked her with kind words.",
    "When Sarah reached the office, she felt nervous.",
    "Her manager welcomed her with a handshake.",
    "The team introduced themselves one by one.",
    "She received her employee ID card.",
    "Her desk was near a large window.",
    "She spent the morning learning the company software.",
    "A colleague helped her solve a login problem.",
    "At lunch, everyone invited Sarah to join them.",
    "She made her first new friend at work.",
    "The afternoon meeting discussed a new project.",
    "Sarah volunteered to help with the presentation.",
    "She took careful notes during the meeting.",
    "Her confidence started to grow.",
    "The project required teamwork and communication.",
    "She stayed focused throughout the day.",
    "Her manager appreciated her enthusiasm.",
    "Sarah completed her first assigned task.",
    "She received positive feedback.",
    "Before leaving, she organized her desk.",
    "She thanked her teammates for their support.",
    "The rain had stopped by the evening.",
    "Sarah walked to the bus stop with a smile.",
    "She reflected on everything she had learned.",
    "She called her parents on the way home.",
    "They were proud of her achievement.",
    "At home, she made herself a cup of tea.",
    "She reviewed her notes once again.",
    "She planned her goals for the next day.",
    "Her confidence was much stronger than in the morning.",
    "She realized that asking questions helped her learn faster.",
    "She decided to improve one skill every week.",
    "She read a chapter from a programming book.",
    "She practiced a few coding exercises.",
    "She solved a difficult bug after several attempts.",
    "That success motivated her to keep learning.",
    "She wrote down ideas in her notebook.",
    "She prepared her clothes for tomorrow.",
    "She set an alarm for the next morning.",
    "Before sleeping, she thanked everyone who had helped her.",
    "She felt grateful for the opportunities ahead.",
    "She closed her notebook and turned off the lights.",
    "The day had been challenging but rewarding.",
    "Sarah fell asleep excited for another productive day."
]

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer()
tokenizer.fit_on_texts(story)
tokenizer.word_counts
# Out:
# OrderedDict([('sarah', 8),
#              ('woke', 1),
#              ('up', 1),
#              ('early', 1),
#              ('to', 8),
#              ('prepare', 1),
#              ('for', 7),
#              ('her', 28),
#              ('first', 3),
#              ('day', 5),
#              ('at', 4),
#              ('work', 2),
#              ('she', 29),
#              ('looked', 1),
#              ('outside', 1),
#              ('and', 3),
#              ('saw', 1),
#              ('heavy', 1),
#              ('rain', 2),
#              ('falling', 1),
#              ('umbrella', 1),
#              ('was', 3),
#              ('broken', 1),
#              ('so', 1),
#              ('borrowed', 1),
#              ('one', 4),
#              ('from', 2),
#              ('neighbor', 1),
#              ('the', 22),
#              ('bus', 2),
#              ('arrived', 1),
#              ('ten', 1),
#              ('minutes', 1),
#              ('late', 1),
#              ('met', 1),
# ...

# %%
a = tokenizer.texts_to_sequences(story)

# %%
from keras.utils import pad_sequences
a = pad_sequences(a,padding="post")
a
# Out:
# array([[  5,  47,  48,  49,   6,  50,   7,   2,  13,   8,   9,  20],
#        [  1,  51,  52,  14,  53,  54,  21,  55,   0,   0,   0,   0],
#        [  2,  56,  15,  57,  58,   1,  59,  10,  22,   2,  60,   0],
#        [  3,  23,  61,  62,  63,  64,   0,   0,   0,   0,   0,   0],
#        [  1,  65,  24,  66,  16,  25,  67,  68,   0,   0,   0,   0],
#        [  5,  69,   2,  70,   6,   3,  16,   0,   0,   0,   0,   0],
#        [  3,  16,  17,   2,  11,  71,  72,   0,   0,   0,   0,   0],
#        [ 73,   5,  74,   3,  75,   1,  26,  76,   0,   0,   0,   0],
#        [  2,  27,  77,   2,  11,   4,  78,   0,   0,   0,   0,   0],
#        [  3,  79,  80,  81,  10,  28,  10,   0,   0,   0,   0,   0],
#        [  1,  29,   2,  82,  83,  84,   0,   0,   0,   0,   0,   0],
#        [  2,  30,  15,  85,   4,  86,  87,   0,   0,   0,   0,   0],
#        [  1,  88,   3,  18,  31,   3,  89,  90,   0,   0,   0,   0],
#        [  4,  91,  19,   2,  92,   4,  93,  94,   0,   0,   0,   0],
# ...

# %%
from keras.datasets import imdb

# %%
(X_train,y_train),(X_test,y_test)=imdb.load_data()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
X_train = pad_sequences(X_train)
X_test = pad_sequences(X_test)

# %%
from keras import Sequential
from keras.layers import Dense,Flatten,SimpleRNN,Embedding

# %%
model = Sequential()

model.add(SimpleRNN(64, input_shape=(X_train.shape[1], 1), return_sequences=True))
model.add(SimpleRNN(64, return_sequences=True))
model.add(SimpleRNN(64, return_sequences=False))
model.add(Dense(64, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_16 (SimpleRNN)       │ (None, 2494, 64)       │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_17 (SimpleRNN)       │ (None, 2494, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_18 (SimpleRNN)       │ (None, 64)             │         8,256 │
# ...

# %%
model.compile(loss="binary_crossentropy",optimizer="adam",metrics=["accuracy"])
model.fit(X_train,y_train,epochs=2, validation_data=(X_test,y_test))
# Out:
# Epoch 1/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 412s 522ms/step - accuracy: 0.5035 - loss: 0.6951 - val_accuracy: 0.5002 - val_loss: 0.6932
# Epoch 2/2
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 403s 515ms/step - accuracy: 0.4993 - loss: 0.6935 - val_accuracy: 0.4992 - val_loss: 0.6937
