# %% [markdown]
# <a href="https://colab.research.google.com/github/zeeshan3106/Deep-Learning/blob/main/Data%20Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
img = image.load_img("images (11).jfif", target_size=(200,200))
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
data = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode="nearest"

)

# %%
img = image.img_to_array(img)
img.shape
img = img.reshape(1,200,200,3)
i=0
for output in data.flow(img,batch_size=1,save_to_dir="aug"):
  i = i+1
  plt.subplot(3,4,i)
  plt.imshow(output[0].astype("uint8"))
  if i ==10:
    break
